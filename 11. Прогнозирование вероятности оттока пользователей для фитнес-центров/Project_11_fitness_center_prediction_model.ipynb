# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Шаг-1.-Загрузка-данных" data-toc-modified-id="Шаг-1.-Загрузка-данных-0.1"><span class="toc-item-num">0.1&nbsp;&nbsp;</span><a href="#step_1">Шаг 1. Загрузка данных</a></a></span></li><li><span><a href="#Шаг-2.-Исследовательский-анализ-данных-(EDA)" data-toc-modified-id="Шаг-2.-Исследовательский-анализ-данных-(EDA)-0.2"><span class="toc-item-num">0.2&nbsp;&nbsp;</span><a href="#step_2">Шаг 2. Исследовательский анализ данных (EDA)</a></a></span></li><li><span><a href="#Шаг-3.-Построение-модели-прогнозирования-оттока-клиентов" data-toc-modified-id="Шаг-3.-Построение-модели-прогнозирования-оттока-клиентов-0.3"><span class="toc-item-num">0.3&nbsp;&nbsp;</span><a href="#step_3">Шаг 3. Построение модели прогнозирования оттока клиентов</a></a></span></li><li><span><a href="#Шаг-4.-Кластеризация-клиентов" data-toc-modified-id="Шаг-4.-Кластеризация-клиентов-0.4"><span class="toc-item-num">0.4&nbsp;&nbsp;</span><a href="#step_4">Шаг 4. Кластеризация клиентов</a></a></span></li><li><span><a href="#Шаг-5.-Выводы" data-toc-modified-id="Шаг-5.-Выводы-0.5"><span class="toc-item-num">0.5&nbsp;&nbsp;</span><a href="#step_5">Шаг 5. Выводы</a></a></span></li><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-0.6"><span class="toc-item-num">0.6&nbsp;&nbsp;</span>Описание данных</a></span></li></ul></li><li><span><a href="#Загрузка-данных" data-toc-modified-id="Загрузка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Загрузка данных</a></span></li><li><span><a href="#Исследовательский-анализ-данных-(EDA)" data-toc-modified-id="Исследовательский-анализ-данных-(EDA)-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Исследовательский анализ данных (EDA)</a></span><ul class="toc-item"><li><span><a href="#Общая-информация" data-toc-modified-id="Общая-информация-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Общая информация</a></span></li><li><span><a href="#Распределение-числовых-признаков" data-toc-modified-id="Распределение-числовых-признаков-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Распределение числовых признаков</a></span></li><li><span><a href="#Средние-значения-признаков-по-группам" data-toc-modified-id="Средние-значения-признаков-по-группам-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Средние значения признаков по группам</a></span></li><li><span><a href="#Матрица-корреляций-признаков" data-toc-modified-id="Матрица-корреляций-признаков-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Матрица корреляций признаков</a></span></li><li><span><a href="#Заключение" data-toc-modified-id="Заключение-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Заключение</a></span></li></ul></li><li><span><a href="#Построение-модели-прогнозирования-оттока-клиентов" data-toc-modified-id="Построение-модели-прогнозирования-оттока-клиентов-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Построение модели прогнозирования оттока клиентов</a></span><ul class="toc-item"><li><span><a href="#Разбивка-данных" data-toc-modified-id="Разбивка-данных-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Разбивка данных</a></span></li><li><span><a href="#Обучение-моделей-и-оценка-метрик" data-toc-modified-id="Обучение-моделей-и-оценка-метрик-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Обучение моделей и оценка метрик</a></span></li><li><span><a href="#Заключение" data-toc-modified-id="Заключение-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Заключение</a></span></li></ul></li><li><span><a href="#Кластеризация-клиентов" data-toc-modified-id="Кластеризация-клиентов-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Кластеризация клиентов</a></span><ul class="toc-item"><li><span><a href="#Матрица-расстояний-и-дендрограмма" data-toc-modified-id="Матрица-расстояний-и-дендрограмма-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Матрица расстояний и дендрограмма</a></span></li><li><span><a href="#Средние-значения-признаков" data-toc-modified-id="Средние-значения-признаков-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Средние значения признаков</a></span><ul class="toc-item"><li><span><a href="#Кластер-0" data-toc-modified-id="Кластер-0-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Кластер 0</a></span></li><li><span><a href="#Кластер-1" data-toc-modified-id="Кластер-1-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Кластер 1</a></span></li><li><span><a href="#Кластер-2" data-toc-modified-id="Кластер-2-4.2.3"><span class="toc-item-num">4.2.3&nbsp;&nbsp;</span>Кластер 2</a></span></li><li><span><a href="#Кластер-3" data-toc-modified-id="Кластер-3-4.2.4"><span class="toc-item-num">4.2.4&nbsp;&nbsp;</span>Кластер 3</a></span></li><li><span><a href="#Кластер-4" data-toc-modified-id="Кластер-4-4.2.5"><span class="toc-item-num">4.2.5&nbsp;&nbsp;</span>Кластер 4</a></span></li></ul></li><li><span><a href="#Распределение-признаков-для-кластеров" data-toc-modified-id="Распределение-признаков-для-кластеров-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Распределение признаков для кластеров</a></span><ul class="toc-item"><li><span><a href="#Числовые-признаки" data-toc-modified-id="Числовые-признаки-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Числовые признаки</a></span></li><li><span><a href="#Категориальные-признаки" data-toc-modified-id="Категориальные-признаки-4.3.2"><span class="toc-item-num">4.3.2&nbsp;&nbsp;</span>Категориальные признаки</a></span></li></ul></li><li><span><a href="#Доля-оттока-по-кластерам" data-toc-modified-id="Доля-оттока-по-кластерам-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Доля оттока по кластерам</a></span></li><li><span><a href="#Заключение" data-toc-modified-id="Заключение-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Заключение</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li></ul></div>

# %% [markdown]
# # Cтратегия взаимодействия с клиентами для сети фитнес-центров «Культурист-датасаентист»
#
# Сеть фитнес-центров «Культурист-датасаентист» разрабатывает стратегию взаимодействия с клиентами на основе аналитических данных.
# Распространённая проблема фитнес-клубов и других сервисов — отток клиентов. Чтобы бороться с оттоком, отдел по работе с клиентами «Культуриста-датасаентиста» перевёл в электронный вид множество клиентских анкет.
#
# Задача - провести анализ и подготовить план действий по удержанию клиентов, а именно:
#
# * научиться прогнозировать вероятность оттока (на уровне следующего месяца) для каждого клиента;
# * сформировать типичные портреты клиентов: выделить несколько наиболее ярких групп и охарактеризовать их основные свойства;
# * проанализировать основные признаки, наиболее сильно влияющие на отток;
# * сформулировать основные выводы и разработать рекомендации по повышению качества работы с клиентами:
#    1) выделить целевые группы клиентов;
#    2) предложить меры по снижению оттока;
#    3) определить другие особенности взаимодействия с клиентами.
#
# Анализ выполняется в несколько шагов:
#
# ### [Шаг 1. Загрузка данных](#step_1)
# Необходимо загрузить исходные данные от «Культурист-датасаентист», которые содержат данные на месяц до оттока и факт оттока на определённый месяц. Путь к файлу: `/datasets/gym_churn.csv`
#
# ### [Шаг 2. Исследовательский анализ данных (EDA)](#step_2)
# Необходимо выполнить следующее:
# * Посмотреть на датасет: есть ли в нем отсутствующие признаки, изучить средние значения и стандартные отклонения (`метод describe()`);
# * Посмотреть на средние значения признаков в двух группах — тех, кто ушел в отток и тех, кто остался (`метод groupby()`);
# * Построить столбчатые гистограммы и распределения признаков для тех, кто ушёл (отток) и тех, кто остался (не попали в отток);
# * Построить матрицу корреляций и отобразить её.
#
# ### [Шаг 3. Построение модели прогнозирования оттока клиентов](#step_3)
# Необходимо построить модель бинарной классификации клиентов, где целевой признак — факт оттока клиента в следующем месяце:
# * Разбить данные на обучающую и валидационную выборку функцией `train_test_split()`.
# * Обучить модель на train-выборке двумя способами:
#    * логистической регрессией,
#    * случайным лесом.
# * Оценить метрики accuracy, precision и recall для обеих моделей на валидационной выборке. Сравнить по ним модели. Ответить на вопрос "Какая модель показала себя лучше на основании метрик?".
#
# Примечание: также требуется указать параметр `random_state` при разделении выборки и задании алгоритма.
#
# ### [Шаг 4. Кластеризация клиентов](#step_4)
# Необходимо отложить в сторону столбец с оттоком и провести кластеризацию объектов (клиентов):
# * Стандартизировать данные.
# * Построить матрицу расстояний функцией `linkage()` на стандартизованной матрице признаков и нарисовать дендрограмму. На основании полученного графика предположить, какое количество кластеров можно выделить.
# * Обучить модель кластеризации на основании алгоритма K-Means и спрогнозировать кластеры клиентов.
# * Посмотреть на средние значения признаков для кластеров. Можно ли сразу что-то заметить?
# * Построить распределения признаков для кластеров. Можно ли что-то заметить по ним?
# * Для каждого полученного кластера посчитать долю оттока (метод `groupby()`). Отличаются ли они по доле оттока? Какие кластеры склонны к оттоку, а какие — надёжны?
#
# ### [Шаг 5. Выводы](#step_5)
# Сформулировать основные выводы и предложить рекомендации для стратегии взаимодействия с клиентами и их удержания.
# Не описывать стратегию детально: достаточно 3-4 важных принципов и примеров их реализации в виде определённых маркетинговых действий.
#
# ### Описание данных
# Набор данных включает следующие поля:
#
# Данные клиента за предыдущий до проверки факта оттока месяц:
# * `gender` — пол;
# * `Near_Location` — проживание или работа в районе, где находится фитнес-центр;
# * `Partner` — сотрудник компании-партнёра клуба (сотрудничество с компаниями, чьи сотрудники могут получать скидки на абонемент — в таком случае фитнес-центр хранит информацию о работодателе клиента);
# * `Promo_friends` — факт первоначальной записи в рамках акции «приведи друга» (использовал промо-код от знакомого при оплате первого абонемента);
# * `Phone` — наличие контактного телефона;
# * `Age` — возраст;
# * `Lifetime` — время с момента первого обращения в фитнес-центр (в месяцах).
#
# Информация на основе журнала посещений, покупок и информация о текущем статусе абонемента клиента:
# * `Contract_period` — длительность текущего действующего абонемента (месяц, 6 месяцев, год);
# * `Month_to_end_contract` — срок до окончания текущего действующего абонемента (в месяцах);
# * `Group_visits` — факт посещения групповых занятий;
# * `Avg_class_frequency_total` — средняя частота посещений в неделю за все время с начала действия абонемента;
# * `Avg_class_frequency_current_month` — средняя частота посещений в неделю за предыдущий месяц;
# * `Avg_additional_charges_total` — суммарная выручка от других услуг фитнес-центра: кафе, спорттовары, косметический и массажный салон.
#
# `Churn` — факт оттока в текущем месяце.

# %% [markdown]
# <a id="step_1"> </a>
# ## Загрузка данных

# %%
# импорт библиотек
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.cluster import KMeans
from scipy.cluster.hierarchy import dendrogram, linkage

from sklearn.metrics import accuracy_score, precision_score, recall_score

# %%
# чтение файла с данными и сохранение в df:
df = pd.read_csv('/datasets/gym_churn.csv')

# %%
# получение первых 10 строк таблицы df:
df.head(10)
# Out:
#    gender  Near_Location  Partner  Promo_friends  Phone  Contract_period  \
# 0       1              1        1              1      0                6
# 1       0              1        0              0      1               12
# 2       0              1        1              0      1                1
# 3       0              1        1              1      1               12
# 4       1              1        1              1      1                1
# 5       1              1        0              0      1                1
# 6       1              1        1              1      0                6
# 7       0              1        0              0      1                1
# 8       1              1        1              1      1                1
# 9       0              1        0              0      1                1
#
#    Group_visits  Age  Avg_additional_charges_total  Month_to_end_contract  \
# 0             1   29                     14.227470                    5.0
# ...

# %%
# получение общей информации о данных в таблице df:
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   gender                             4000 non-null   int64
#  1   Near_Location                      4000 non-null   int64
#  2   Partner                            4000 non-null   int64
#  3   Promo_friends                      4000 non-null   int64
#  4   Phone                              4000 non-null   int64
#  5   Contract_period                    4000 non-null   int64
#  6   Group_visits                       4000 non-null   int64
#  7   Age                                4000 non-null   int64
#  8   Avg_additional_charges_total       4000 non-null   float64
#  9   Month_to_end_contract              4000 non-null   float64
#  10  Lifetime                           4000 non-null   int64
# ...

# %% [markdown]
# Предлагается выполнить небольшую предобработку данных для последующего анализа:
# * привести названия столбцов к змеиному регистру
# * изменить тип данных в столбце `month_to_end_contract` на `int64`

# %%
# приведение столбцов к змеиному регистру
df.columns = df.columns.str.lower()

# %%
# изменение типа данных
df['month_to_end_contract'] = df['month_to_end_contract'].astype('int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   gender                             4000 non-null   int64
#  1   near_location                      4000 non-null   int64
#  2   partner                            4000 non-null   int64
#  3   promo_friends                      4000 non-null   int64
#  4   phone                              4000 non-null   int64
#  5   contract_period                    4000 non-null   int64
#  6   group_visits                       4000 non-null   int64
#  7   age                                4000 non-null   int64
#  8   avg_additional_charges_total       4000 non-null   float64
#  9   month_to_end_contract              4000 non-null   int64
#  10  lifetime                           4000 non-null   int64
# ...

# %% [markdown]
# <a id="step_2"> </a>
# ## Исследовательский анализ данных (EDA)

# %% [markdown]
# ### Общая информация

# %%
# размер датасета
df.shape
# Out:
# (4000, 14)

# %%
# получение общей информации о пропусках данных в таблице:
df.isna().mean().sort_values(ascending=False)
# Out:
# gender                               0.0
# near_location                        0.0
# partner                              0.0
# promo_friends                        0.0
# phone                                0.0
# contract_period                      0.0
# group_visits                         0.0
# age                                  0.0
# avg_additional_charges_total         0.0
# month_to_end_contract                0.0
# lifetime                             0.0
# avg_class_frequency_total            0.0
# avg_class_frequency_current_month    0.0
# churn                                0.0
# dtype: float64

# %% [markdown]
# Пропуски в датасете отсутствуют, предварительно выделим тип признаков (числовые/категориальные) целевой переменной `churn` (категориальная, отражает факт оттока в текущем месяце):

# %%
col = []
type = []

for sign in df.columns:
    col.append(sign)
    if df[sign].nunique() < 10:
        type.append('Категориальный')
    else:
        type.append('Числовой')

print(pd.DataFrame(list(zip(col, type)), columns=['Признак', 'Тип']))
# Out:
#                               Признак             Тип
# 0                              gender  Категориальный
# 1                       near_location  Категориальный
# 2                             partner  Категориальный
# 3                       promo_friends  Категориальный
# 4                               phone  Категориальный
# 5                     contract_period  Категориальный
# 6                        group_visits  Категориальный
# 7                                 age        Числовой
# 8        avg_additional_charges_total        Числовой
# 9               month_to_end_contract        Числовой
# 10                           lifetime        Числовой
# 11          avg_class_frequency_total        Числовой
# 12  avg_class_frequency_current_month        Числовой
# 13                              churn  Категориальный

# %% [markdown]
# В целом, отсутствующих признаков целевой переменной не наблюдается. Рассмотрим средние значения и стандартные отклонения:

# %%
df.describe().T
# Out:
#                                     count        mean        std        min  \
# gender                             4000.0    0.510250   0.499957   0.000000
# near_location                      4000.0    0.845250   0.361711   0.000000
# partner                            4000.0    0.486750   0.499887   0.000000
# promo_friends                      4000.0    0.308500   0.461932   0.000000
# phone                              4000.0    0.903500   0.295313   0.000000
# contract_period                    4000.0    4.681250   4.549706   1.000000
# group_visits                       4000.0    0.412250   0.492301   0.000000
# age                                4000.0   29.184250   3.258367  18.000000
# avg_additional_charges_total       4000.0  146.943728  96.355602   0.148205
# month_to_end_contract              4000.0    4.322750   4.191297   1.000000
# lifetime                           4000.0    3.724750   3.749267   0.000000
# ...

# %% [markdown]
# <a id="conclusion_2.1"> </a>
# Можно выделить следующие характерные особенности по средним значениям:
# * 51% клиентов имеет пол 1 (к сожалению не указано, что соответствует единице и нулю - мужчины или женщины), в целом можно сказать, что практически соблюдается гендерное равенство
# * преобладающее количество клиентов (84,5%) проживает или работает в районе, где находится фитнес-центр
# * 48,7% клиентов - сотрудники компании-партнера клуба
# * лишь 30,1% клиентов пришли по акции "приведи друга"
# * у 90% клиентов указан контактный телефон
# * средняя длительность текущего действующего абонемента составляет почти 5 месяцев, однако подавляющее количество абонементов - 1 месяц (медианное значение)
# * лишь 41% клиентов посетил групповые занятия
# * средний возраст клиента - 29 лет
# * суммарная средняя выручка от других услуг - 147 рублей (?)
# * средний срок до окончания текущего действующего абонемента - 4,3 месяца (медианное значение - 1 месяц)
# * средний срок с момента первого обращения в фитнес-центр - 3,7 месяца (медианное значение - 3 месяца)
# * средняя частота посещений в неделю за все время - 1,88 (близко к 2)
# * средняя частота посещений в неделю за предыдущий месяц - 1,77
# * 26,5% клиентов в текущем месяце ушли (отток)

# %% [markdown]
# <a id="conclusion_2.2"> </a>
# ### Распределение числовых признаков

# %% [markdown]
# Рассмотрим распределение числовых признаков.

# %%
sns.set(style="whitegrid")

fig = plt.figure(figsize = (15, 30))

ax_1 = fig.add_subplot(4, 2, 1)
ax_2 = fig.add_subplot(4, 2, 2)
ax_3 = fig.add_subplot(4, 2, 3)
ax_4 = fig.add_subplot(4, 2, 4)
ax_5 = fig.add_subplot(4, 2, 5)
ax_6 = fig.add_subplot(4, 2, 6)
ax_7 = fig.add_subplot(4, 2, 7)

sns.histplot(data=df, x='contract_period', bins=12, kde=True, hue='churn', ax=ax_1)
ax_1.set_xlim(left=0, right=12)
ax_1.set_ylim(bottom=0, top=3000)
ax_1.set(title ="Распределение длительности текущего действующего абонемента", 
            xlabel='Длительность текущего действующего абонемента (месяцев)', 
            ylabel='Количество абонементов');

sns.histplot(data=df, x='age', bins=24, kde=True, hue='churn', ax=ax_2)
ax_2.set_xlim(left=15, right=45)
ax_2.set_ylim(bottom=0, top=500)
ax_2.set(title ="Распределение возраста клиентов", 
            xlabel='Возраст клиента (лет)', 
            ylabel='Количество клиентов');

sns.histplot(data=df, x='avg_additional_charges_total', bins=100, kde=True, hue='churn', ax=ax_3)
ax_3.set_xlim(left=0, right=600)
ax_3.set_ylim(bottom=0, top=200)
ax_3.set(title ="Распределение выручки от дополнительных услуг", 
            xlabel='Выручка от дополнительных услуг (руб.)', 
            ylabel='Количество клиентов');

sns.histplot(data=df, x='month_to_end_contract', bins=12, kde=True, hue='churn', ax=ax_4)
ax_4.set_xlim(left=0, right=12)
ax_4.set_ylim(bottom=0, top=3000)
ax_4.set(title ="Распределение срока до окончания текущего действующего абонемента", 
            xlabel='Срок до окончания текущего действующего абонемента (месяцев)', 
            ylabel='Количество клиентов');

sns.histplot(data=df, x='lifetime', bins=31, kde=True, hue='churn', ax=ax_5)
ax_5.set_xlim(left=0, right=35)
ax_5.set_ylim(bottom=0, top=1000)
ax_5.set(title ="Распределение времени с момента первого обращения", 
            xlabel='Время с момента первого обращения (месяцев)', 
            ylabel='Количество клиентов');

sns.histplot(data=df, x='avg_class_frequency_total', bins=50, kde=True, hue='churn', ax=ax_6)
ax_6.set_xlim(left=0, right=7)
ax_6.set_ylim(bottom=0, top=300)
ax_6.set(title ="Распределение средней частоты посещений в неделю за все время", 
            xlabel='Средняя частота посещений в неделю за все время', 
            ylabel='Количество клиентов');

sns.histplot(data=df, x='avg_class_frequency_current_month', bins=50, kde=True, hue='churn', ax=ax_7)
ax_7.set_xlim(left=0, right=7)
ax_7.set_ylim(bottom=0, top=300)
ax_7.set(title ="Распределение средней частоты посещений в неделю за предыдущий месяц", 
            xlabel='Средняя частота посещений в неделю за предыдущий месяц', 
            ylabel='Количество клиентов');

# %% [markdown]
# `contract_period`

# %% [markdown]
# Преимущественно преобладают абонементы на один месяц, а годовых абонементов больше, чем полугодовых. Всего наблюдается три типа абонемента по длительности:
# * месяц
# * 6 месяцев
# * 12 месяцев
#
# Таким образом, можно также считать эту переменную категориальной и использовать для кластеризации.
#
# Для группы с оттоком более характерны месячные абонементы, а годовые абонементы скорее исключение.

# %% [markdown]
# `age`

# %% [markdown]
# Имеем нормальное распределение, что также можно заметить по близким среднему и медианному значениям возраста.
#
# Клиенты группы с оттоком в среднем моложе на пару лет.

# %% [markdown]
# `avg_additional_charges_total`

# %%
print(f'Средняя суммарная дополнительная выручка - {round(df["avg_additional_charges_total"].mean(), 2)} руб.')
print(f'Медианная суммарная дополнительная выручка - {round(df["avg_additional_charges_total"].median(), 2)} руб.')
# Out:
# Средняя суммарная дополнительная выручка - 146.94 руб.
# Медианная суммарная дополнительная выручка - 136.22 руб.

# %% [markdown]
# Имеем датасет с положительной скошенностью (скошенный вправо). Это также можно заметить по тому факту, что среднее значение суммарной дополнительной выручки больше медианного.
#
# Количество клиентов группы с оттоком значительно меньше (но это видно и из общей информации - раздел 2.1).

# %% [markdown]
# `month_to_end_contract`

# %%
print(f'Средний срок до окончания абонемента - {round(df["month_to_end_contract"].mean(), 1)} месяцев')
print(f'Медианный срок до окончания абонемента - {round(df["month_to_end_contract"].median(), 1)} месяцев')
# Out:
# Средний срок до окончания абонемента - 4.3 месяцев
# Медианный срок до окончания абонемента - 1.0 месяцев

# %% [markdown]
# В данном случае распределение четко коррелирует с переменной `contract_period`, т.е. наблюдаются локальные максимумы вблизи 1, 6 и 12 месяцев.

# %% [markdown]
# `lifetime`

# %%
print(f'Средний срок до окончания абонемента - {round(df["lifetime"].mean(), 1)} месяцев')
print(f'Медианный срок до окончания абонемента - {round(df["lifetime"].median(), 1)} месяцев')
# Out:
# Средний срок до окончания абонемента - 3.7 месяцев
# Медианный срок до окончания абонемента - 3.0 месяцев

# %% [markdown]
# Имеем датасет с положительной скошенностью (скошенный вправо). Это также можно заметить по тому факту, что среднее значение времени с момента первого обращения больше медианного. В целом, подавляющая часть клиентов обратилась не позднее чем 18 месяцев назад (полтора года).
#
# Для клиентов группы с оттоком характерно гораздо меньшее время с момента первого обращения.

# %% [markdown]
# `avg_class_frequency_total`

# %%
print(f'Среднее количество посещений в неделю - {round(df["avg_class_frequency_total"].mean(), 1)} раз')
print(f'Медианное количество посещений в неделю - {round(df["avg_class_frequency_total"].median(), 1)} раз')
# Out:
# Среднее количество посещений в неделю - 1.9 раз
# Медианное количество посещений в неделю - 1.8 раз

# %% [markdown]
# Имеем датасет с положительной скошенностью (скошенный вправо). Это также можно заметить по тому факту, что среднее значение частоты посещений в неделю за все время больше медианного.
#
# Клиенты группы с оттоком посещают фитнес-центр существенно реже, чем "постоянные" клиенты.

# %% [markdown]
# `avg_class_frequency_current_month`

# %%
print(f'Среднее количество посещений в неделю - {round(df["avg_class_frequency_current_month"].mean(), 1)} раз')
print(f'Медианное количество посещений в неделю - {round(df["avg_class_frequency_current_month"].median(), 1)} раз')
# Out:
# Среднее количество посещений в неделю - 1.8 раз
# Медианное количество посещений в неделю - 1.7 раз

# %% [markdown]
# Характер распределения такой же, как и для предыдущего признака `avg_class_frequency_total`. Однако, среднее количество посещений меньше, а доля посетителей с нулевыми посещениями выросла. Рассмотрим подробнее:

# %%
print(f'Доля посетителей с нулевым посещением за все время - '
      f'{df.query("avg_class_frequency_total == 0").shape[0] / df.shape[0]:.1%}')

print(f'Доля посетителей с нулевым посещением за предыдущий месяц - '
      f'{df.query("avg_class_frequency_current_month == 0").shape[0] / df.shape[0]:.1%}')
# Out:
# Доля посетителей с нулевым посещением за все время - 2.2%
# Доля посетителей с нулевым посещением за предыдущий месяц - 4.5%

# %% [markdown]
# Также заметно, что существенная часть клиентов группы с оттоком вообще не посещала фитнес-центр в предыдущем месяце.

# %% [markdown]
# ### Средние значения признаков по группам

# %% [markdown]
# Подготовим таблицу `sign_mean`, в которой будут указаны средние значения признаков по группам - тех, кто ушел в отток и тех, кто остался:

# %%
sign_mean = df.groupby('churn').mean()
sign_mean
# Out:
#          gender  near_location   partner  promo_friends     phone  \
# churn
# 0      0.510037       0.873086  0.534195       0.353522  0.903709
# 1      0.510839       0.768143  0.355325       0.183789  0.902922
#
#        contract_period  group_visits        age  avg_additional_charges_total  \
# churn
# 0             5.747193      0.464103  29.976523                    158.445715
# 1             1.728558      0.268615  26.989632                    115.082899
#
#        month_to_end_contract  lifetime  avg_class_frequency_total  \
# churn
# 0                   5.283089  4.711807                   2.024876
# 1                   1.662582  0.990575                   1.474995
#
#        avg_class_frequency_current_month
# churn
# 0                               2.027882
# 1                               1.044546

# %% [markdown]
# Для наглядности построим столбчатые диаграммы по признакам для обеих групп:

# %%
fig, axes = plt.subplots(5, 3, figsize=(9, 18), constrained_layout=True)
axes = axes.ravel()

for sign, ax in zip(sign_mean.columns, axes):
    ax.set_title(sign)
    ax=sns.barplot(data=sign_mean, x=sign_mean.index, y=sign, ax=ax)

fig.delaxes(axes[13])
fig.delaxes(axes[14])

# %% [markdown]
# <a id="conclusion_2.3"> </a>
# Наблюдается следующее:
# 1. В группах сохраняется гендерное равенство (количество посетителей обоих полов примерно одинаковое).
# 2. Среди тех, кто ушел в отток, значительно меньше людей, проживающих или работающих в районе, где находится фитнес-центр.
# 3. Среди тех, кто ушел в отток, существенно меньше сотрудников компании-партнера клуба.
# 4. Среди тех, кто ушел в отток, также существенно меньше людей, которые пришли в рамках акции "приведи друга".
# 5. В обих группах примерно одинаковое количество людей, у которых указан контактный телефон.
# 6. Длительность текущего действующего абонемента для тех, кто ушел в отток, примерно в три раза меньше, чем для другой группы.
# 7. Клиенты группы, кто ушел в отток, примерно в два раза реже пользуются групповыми занятиями.
# 8. Возраст клиентов обеих групп примерно одинаковый (разница, на первый взгляд, не столь существенная - 30 и 27 лет).
# 9. Клиенты группы, кто ушел в отток, генерируют значительно меньше суммарной выручки от других услуг фитнес-центра.
# 10. Срок до окончания текущего действующего абонемента среди тех, кто ушел в отток, примерно в три раза меньше, чем у другой группы.
# 11. Время с момента первого обращения в фитнес-центр отличается почти в 5 раз для указанных групп.
# 12. При рассмотрении средней частоты посещений в неделю за все время заметно, что клиенты группы, кто ушел в оток, реже посещают фитнес-центр. При рассмотрении средней частоты посещений в неделю за предыдущий месяц эта разница существено увеличивается (1 раз в неделю против 2).

# %% [markdown]
# ### Матрица корреляций признаков

# %% [markdown]
# Посстроим корреляционную матрицу признаков набора данных:

# %%
corr_m = df.corr()

# %% [markdown]
# Визуализируем полученную корреляционную матрицу методом `heatmap()`:

# %%
plt.figure(figsize=(14,14))
sns.heatmap(corr_m, square = True, annot = True, cmap='coolwarm')
plt.show()

# %% [markdown]
# <a id="conclusion_2.4"> </a>
# По тепловой карте можно выделить следующие основные факторы, которые существенно влияют на целевую переменную `churn`:
# * `contract_period`
# * `age`
# * `month_to_end_contract`
# * `lifetime`
# * `avg_class_frequency_current_month`
#
# Влияние указанных факторов оценивается как среднее умеренное отрицательное, т.е. при снижении значений данных факторов вероятность оттока возрастает.
#
# Дополнительно выделим факторы, которые характеризуются слабым отрицательным влиянием:
# * `near_location`
# * `partner`
# * `promo_friends`
# * `group_visits`
# * `avg_additional_charges_total`
# * `avg_class_frequency_total`
#
# Два оставшихся фактора, которыми можно совсем пренебречь:
# * `gender`
# * `phone`

# %% [markdown]
# **Примечание**
# для оценки тесноты связи между признаками используется следующая таблица по шкале Чеддока:

# %% [markdown]
# ![%D0%A8%D0%BA%D0%B0%D0%BB%D0%B0%20%D0%A7%D0%B5%D0%B4%D0%B4%D0%BE%D0%BA%D0%B0.png](attachment:%D0%A8%D0%BA%D0%B0%D0%BB%D0%B0%20%D0%A7%D0%B5%D0%B4%D0%B4%D0%BE%D0%BA%D0%B0.png)

# %% [markdown]
# Также имеются две пары мультиколлинеарных признаков:
# 1. `contract_period` и `month_to_end_contract`
# 2. `avg_class_frequency_total` и `avg_class_frequency_current_month`
#
# Мультиколлинеарность негативно влияет на модели машинного обучения. Для линейных моделей возникают следующие проблемы:
# * нерепрезентативные веса
# * переобученная под эти признаки модель
#
# Чтобы избавиться от мультиколлинеарности, удаляют один из признаков (пример):

# %%
#df.drop('month_to_end_contract', axis = 1, inplace = True)
#df.drop('avg_class_frequency_current_month', axis = 1, inplace = True)

# %% [markdown]
# ### Заключение

# %% [markdown]
# 1. Получена общая информация по данным, выделены характерные особенности по средним значениям ([см. раздел 2.1](#conclusion_2.1)).
# 2. Изучено распределение числовых признаков целевой переменной `churn` ([см. раздел 2.2](#conclusion_2.2)).
# 3. Рассмотрены средние значения признаков целевой переменной `churn` по группам - тех, кто ушел в отток и тех, кто остался ([см. раздел 2.3](#conclusion_2.3)).
# 4. Построена тепловая карта матрицы корреляций признаков набора данных, факторы выделены в отдельные категории по степени влияния на целевую переменную `churn` ([см. раздел 2.4](#conclusion_2.4)).
# 5. Обнаружены две пары мультиколлинеарных признаков:
# * `contract_period` и `month_to_end_contract`
# * `avg_class_frequency_total` и `avg_class_frequency_current_month`

# %% [markdown]
# <a id="step_3"> </a>
# ## Построение модели прогнозирования оттока клиентов

# %% [markdown]
# ### Разбивка данных

# %% [markdown]
# Разделим полученные данные на признаки (матрица X) и целевую переменную (y):

# %%
X = df.drop(columns=['churn'], axis=1)
y = df['churn']

# %% [markdown]
# Разделим модель на обучающую и валидационную выборку в соотношении 80 к 20:

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# Стандартизируем данные:

# %%
scaler = StandardScaler()
X_train_st = scaler.fit_transform(X_train)
X_test_st = scaler.transform(X_test)

# %% [markdown]
# ### Обучение моделей и оценка метрик

# %% [markdown]
# Согласно Техническому заданию необходимо обучить модель на train-выборке двумя способами:
# * логистической регрессией - `LogisticRegression()`
# * случайным лесом - `RandomForestRegressor()`.
#
# Также требуется оценить метрики accuracy, precision и recall для обеих моделей на валидационной выборке.
# Зададим список моделей:

# %%
models = [LogisticRegression(random_state=0),
          RandomForestClassifier(n_estimators = 100, random_state = 0)
         ]

# %%
# функция, которая принимает на вход модель и данные и выводит метрики
def make_prediction(m):
    model = m
    model.fit(X_train_st, y_train)
    y_pred = model.predict(X_test_st)
    acc = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    print('Значения метрик:')
    print(f'accuracy - {round(acc, 3)}')
    print(f'precision - {round(precision, 3)}')
    print(f'recall - {round(recall, 3)}')
    print()

# %% [markdown]
# Выведем метрики по списку моделей:

# %%
for i in models:
    print(i)
    make_prediction(m=i)
# Out:
# LogisticRegression(random_state=0)
# Значения метрик:
# accuracy - 0.922
# precision - 0.854
# recall - 0.828
#
# RandomForestClassifier(random_state=0)
# Значения метрик:
# accuracy - 0.915
# precision - 0.839
# recall - 0.813

# %% [markdown]
# ### Заключение

# %% [markdown]
# На основании полученных значений метрик можно считать, что модель, обученная логистической регрессией, показала себя лучше. У обеих моделей очень высокие результаты по Accuracy (больше 0,91), а также высокие результаты по Precision и Recall.

# %% [markdown]
# <a id="step_4"> </a>
# ## Кластеризация клиентов

# %% [markdown]
# ### Матрица расстояний и дендрограмма

# %% [markdown]
# Проведем кластеризацию пользователей без столбца целевого значения, а именно:
# * Стандартизируем данные
# * Построим матрицу расстояний функцией linkage() на стандартизированной матрице признаков и нарисуем дендограмму. Предположим, какое количество кластеров можем выделить.
# * Обучим модель кластеризации на основе алгоритма K-Means и спрогнозируем кластеры клиентов. (берём n=5 кластеров)
#
# <a id="conclusion_4.1"> </a>

# %%
X_st = scaler.fit_transform(X)
linked = linkage(X_st, method='ward')
plt.figure(figsize=(15, 10))
dendrogram(linked, orientation='top')
plt.title('\n Иерархическая кластеризация', fontsize=15)
plt.show()
km = KMeans(n_clusters = 5, random_state = 0)
labels = km.fit_predict(X_st)
df['cluster_km'] = labels

# %% [markdown]
# Явно выделяются 4 кластера (по ТЗ рекомендовано использовать 5).

# %% [markdown]
# ### Средние значения признаков

# %% [markdown]
# <a id="conclusion_4.2"> </a>
# Рассмотрим средние значения признаков для кластеров:

# %%
cluster_features = df.groupby('cluster_km').mean()
 
cluster_features.T.style.background_gradient(cmap='coolwarm', axis=1).set_precision(2)
# Out:
# <style  type="text/css" >
# #T_35ceb_row0_col0{
#             background-color:  #86a9fc;
#             color:  #000000;
#         }#T_35ceb_row0_col1{
#             background-color:  #dadce0;
#             color:  #000000;
#         }#T_35ceb_row0_col2,#T_35ceb_row8_col2{
#             background-color:  #6282ea;
#             color:  #000000;
#         }#T_35ceb_row0_col3,#T_35ceb_row1_col2,#T_35ceb_row2_col3,#T_35ceb_row3_col2,#T_35ceb_row4_col1,#T_35ceb_row5_col3,#T_35ceb_row6_col2,#T_35ceb_row7_col3,#T_35ceb_row8_col3,#T_35ceb_row9_col3,#T_35ceb_row10_col3,#T_35ceb_row11_col3,#T_35ceb_row12_col3,#T_35ceb_row13_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
# ...

# %% [markdown]
# Рассмотрим количество примеров в кластерах:

# %%
df.groupby('cluster_km')['gender'].count().sort_values()
# Out:
# cluster_km
# 1     385
# 2     505
# 4     838
# 0    1010
# 3    1262
# Name: gender, dtype: int64

# %% [markdown]
# Выделим для каждого кластера характерные особенности:

# %% [markdown]
# #### Кластер 0

# %% [markdown]
# Для клиентов данного кластера характерно:
# * гендерное равенство (50%)
# * практически все клиенты проживают или работают в районе, где находится фитнес-центр (96%)
# * большая доля клиентов является сотрудниками компании-партнера клуба (78%)
# * больше половины клиентов пришли в рамках акции "приведи друга" (57%)
# * у всех указан контактный телефон
# * практически все клиенты предпочитают годовые контракты
# * больше половины клиентов посещают групповые занятия (54%)
# * средний возраст - 30 лет
# * средняя частота посещений - 2 раза в неделю
#
# **Доля оттока составляет - 3%** (*минимальная*)

# %% [markdown]
# #### Кластер 1

# %% [markdown]
# Для клиентов данного кластера характерно:
# * небольшой перекос в сторону пола 1 (52%)
# * преимущественно проживание или работа в районе, где находится фитнес-центр (86%)
# * чуть меньше половины клиентов является сотрудниками компании-партнера клуба (47%)
# * по акции "приведи друга" обратился всего 31% клиентов.
# * отсутствие контактных телефонов
# * клиенты больше предпочитают полугодовые контракты
# * меньше половины клиентов посещают групповые занятия (43%)
# * средний возраст - 29 лет
# * средняя частота посещений - ближе к 2 разам в неделю
#
# **Доля оттока составляет - 27%**

# %% [markdown]
# #### Кластер 2

# %% [markdown]
# Для клиентов данного кластера характерно:
# * гендерное равенство
# * никто из клиентов не проживает или работает в районе, где находится фитнес-центр (0%)
# * чуть меньше половины клиентов является сотрудниками компании-партнера клуба (46%)
# * по акции "приведи друга" обратилось всего 8% клиентов.
# * у всех указан контактный телефон
# * клиенты предпочитают как одномесячные, так и полугодовые контракты
# * клиенты практически не посещают групповые занятия (22%)
# * средний возраст - 28 лет
# * средняя частота посещений - 1,5 раза в неделю (3 раза в две недели)
#
# **Доля оттока составляет - 44%**

# %% [markdown]
# #### Кластер 3

# %% [markdown]
# Для клиентов данного кластера характерно:
# * клиентов с полом 1 незначительно меньше (49%)
# * все клиенты проживают или работают в районе, где находится фитнес-центр (100%)
# * чуть более трети клиентов является сотрудниками компании-партнера клуба (35%)
# * по акции "приведи друга" обратилось всего 24% клиентов.
# * у всех указан контактный телефон
# * клиенты предпочитают скорее одномесячные контракты
# * чуть больше трети клиентов посещают групповые занятия (34%)
# * средний возраст - 28 лет
# * средняя частота посещений - 1 раз в неделю
#
# **Доля оттока составляет - 51%** (*максимальная*)

# %% [markdown]
# #### Кластер 4

# %% [markdown]
# Для клиентов данного кластера характерно:
# * клиентов с полом 1 ощутимо больше (56%)
# * практически все клиенты проживают или работают в районе, где находится фитнес-центр (98%)
# * чуть более трети клиентов является сотрудниками компании-партнера клуба (36%)
# * по акции "приведи друга" обратилось всего 23% клиентов.
# * у всех указан контактный телефон
# * клиенты предпочитают как одномесячные, так и полугодовые контракты
# * чуть меньше половины клиентов посещают групповые занятия (47%)
# * средний возраст - 30 лет
# * средняя частота посещений - 3 раза в неделю
#
# **Доля оттока составляет - 7%**

# %% [markdown]
# ### Распределение признаков для кластеров

# %% [markdown]
# <a id="conclusion_4.3"> </a>
# Построим распределение признаков для кластеров.

# %% [markdown]
# #### Числовые признаки

# %%
sns.set(style="whitegrid")

fig = plt.figure(figsize = (15, 30))

ax_1 = fig.add_subplot(4, 2, 1)
ax_2 = fig.add_subplot(4, 2, 2)
ax_3 = fig.add_subplot(4, 2, 3)
ax_4 = fig.add_subplot(4, 2, 4)
ax_5 = fig.add_subplot(4, 2, 5)
ax_6 = fig.add_subplot(4, 2, 6)

sns.histplot(data=df, x='age', bins=24, kde=True, hue='cluster_km', ax=ax_1)
ax_1.set_xlim(left=15, right=45)
ax_1.set_ylim(bottom=0, top=200)
ax_1.set(title ="Распределение возраста клиентов", 
            #xlabel='Возраст клиента (лет)', 
            ylabel='Количество клиентов');

sns.histplot(data=df, x='avg_additional_charges_total', bins=100, kde=True, hue='cluster_km', ax=ax_2)
ax_2.set_xlim(left=0, right=600)
ax_2.set_ylim(bottom=0, top=50)
ax_2.set(title ="Распределение выручки от дополнительных услуг", 
            #xlabel='Выручка от дополнительных услуг (руб.)', 
            ylabel='Количество клиентов');

sns.histplot(data=df, x='month_to_end_contract', bins=12, kde=True, hue='cluster_km', ax=ax_3)
ax_3.set_xlim(left=0, right=12)
ax_3.set_ylim(bottom=0, top=1200)
ax_3.set(title ="Распределение срока до окончания текущего действующего абонемента", 
            #xlabel='Срок до окончания текущего действующего абонемента (месяцев)', 
            ylabel='Количество клиентов');

sns.histplot(data=df, x='lifetime', bins=31, kde=True, hue='cluster_km', ax=ax_4)
ax_4.set_xlim(left=0, right=35)
ax_4.set_ylim(bottom=0, top=500)
ax_4.set(title ="Распределение времени с момента первого обращения", 
            #xlabel='Время с момента первого обращения (месяцев)', 
            ylabel='Количество клиентов');

sns.histplot(data=df, x='avg_class_frequency_total', bins=50, kde=True, hue='cluster_km', ax=ax_5)
ax_5.set_xlim(left=0, right=7)
ax_5.set_ylim(bottom=0, top=200)
ax_5.set(title ="Средняя частота посещений в неделю за все время", 
            #xlabel='Средняя частота посещений в неделю за все время', 
            ylabel='Количество клиентов');

sns.histplot(data=df, x='avg_class_frequency_current_month', bins=50, kde=True, hue='cluster_km', ax=ax_6)
ax_6.set_xlim(left=0, right=7)
ax_6.set_ylim(bottom=0, top=200)
ax_6.set(title ="Средняя частота посещений в неделю за предыдущий месяц", 
            #xlabel='Средняя частота посещений в неделю за предыдущий месяц', 
            ylabel='Количество клиентов');

# %% [markdown]
# #### Категориальные признаки

# %%
#sns.set(style="whitegrid")

fig = plt.figure(figsize = (15, 30))

ax_1 = fig.add_subplot(4, 2, 1)
ax_2 = fig.add_subplot(4, 2, 2)
ax_3 = fig.add_subplot(4, 2, 3)
ax_4 = fig.add_subplot(4, 2, 4)
ax_5 = fig.add_subplot(4, 2, 5)
ax_6 = fig.add_subplot(4, 2, 6)
ax_7 = fig.add_subplot(4, 2, 7)
ax_8 = fig.add_subplot(4, 2, 8)

sns.barplot(data=df, x='cluster_km', y='gender', ax=ax_1)
ax_1.set(title ="Гендерное соотношение");

sns.barplot(data=df, x='cluster_km', y='near_location', ax=ax_2)
ax_2.set(title ="Близость к фитнес-центру");

sns.barplot(data=df, x='cluster_km', y='partner', ax=ax_3)
ax_3.set(title ="Сотрудники компании-партнера клуба");

sns.barplot(data=df, x='cluster_km', y='promo_friends', ax=ax_4)
ax_4.set(title ="Акция 'Приведи друга'");

sns.barplot(data=df, x='cluster_km', y='phone', ax=ax_5)
ax_5.set(title ="Наличие контактного телефона");

sns.barplot(data=df, x='cluster_km', y='contract_period', ax=ax_6)
ax_6.set(title ="Длительность абонемента");

sns.barplot(data=df, x='cluster_km', y='group_visits', ax=ax_7)
ax_7.set(title ="Групповые занятия");

sns.barplot(data=df, x='cluster_km', y='churn', ax=ax_8)
ax_8.set(title ="Доля оттока");

# %% [markdown]
# Оценим качественно характер распределений для каждого признака по кластерам:
# 1. `gender` - наблюдается практически гендерное равенство по всем кластерам
# 2. `near_location` - распределения по кластерам серьезным образом отличается
# 3. `partner` - наблюдаются существенные отличия по кластерам
# 4. `promo_friends` - распределения по кластерам серьезным образом отличается
# 5. `phone` - отсутствие контактного телефона характерно лишь для кластера 1
# 6. `contract_period` - есть серьезные отличия по кластерам
# 7. `group_visits` - есть значительные отличия по кластерам
# 8. `age` - нет значительных отличий в распределениях по кластерам
# 9. `avg_additional_charges_total` - нет значительных отличий в распределениях по кластерам
# 10. `month_to_end_contract` - есть значительные отличия по кластерам
# 11. `lifetime` - нет значительных отличий в распределениях по кластерам
# 12. `avg_class_frequency_total` - есть значительные отличия по кластерам
# 13. `avg_class_frequency_current_month` - есть значительные отличия по кластерам
# 14. `churn` - есть значительные отличия по кластерам

# %% [markdown]
# ### Доля оттока по кластерам

# %% [markdown]
# <a id="conclusion_4.4"> </a>
# Отсортируем кластеры по росту доли оттока:

# %%
df.groupby('cluster_km').agg({'churn': 'mean'}).sort_values(by='churn')
# Out:
#                churn
# cluster_km
# 0           0.027723
# 4           0.068019
# 1           0.267532
# 2           0.443564
# 3           0.514263

# %% [markdown]
# В топе по удержанию кластеры 0 и 4, максимальный отток наблюдается в кластерах 2 и 3.
# Рассмотрим подробнее кластеры 0 и 4:

# %%
df.groupby('cluster_km').mean().query('cluster_km == 0 or cluster_km == 4')
# Out:
#               gender  near_location   partner  promo_friends     phone  \
# cluster_km
# 0           0.502970       0.959406  0.783168       0.574257  1.000000
# 4           0.559666       0.976134  0.356802       0.230310  0.998807
#
#             contract_period  group_visits        age  \
# cluster_km
# 0                 10.889109      0.542574  29.982178
# 4                  2.669451      0.473747  30.125298
#
#             avg_additional_charges_total  month_to_end_contract  lifetime  \
# cluster_km
# 0                             160.761016               9.954455  4.736634
# 4                             161.657905               2.459427  4.898568
#
#             avg_class_frequency_total  avg_class_frequency_current_month  \
# cluster_km
# 0                            1.982055                           1.974789
# 4                            2.852002                           2.850161
#
#                churn
# cluster_km
# 0           0.027723
# 4           0.068019

# %% [markdown]
# Можно отметить следующие характерные особенности, близкие для обоих кластеров:
# 1. Гендерное равенство
# 2. Практически все клиенты проживают или работают в районе, где находится фитнес-центр
# 3. Наличие контактного телефона у всех клиентов
# 4. Посещение групповых занятий - примерно половина клиентов
# 5. Возраст - 30 лет
# 6. Одинаковая суммарная выручка от других услуг фитнес-центра
# 7. Время с момента первого обращения - около 5 месяцев
# 8. Количество посещений в неделю - 2 и более

# %% [markdown]
# Рассмотрим подробнее кластеры 2 и 3:

# %%
df.groupby('cluster_km').mean().query('cluster_km == 2 or cluster_km == 3')
# Out:
#               gender  near_location   partner  promo_friends  phone  \
# cluster_km
# 2           0.495050            0.0  0.463366       0.079208    1.0
# 3           0.485737            1.0  0.350238       0.240095    1.0
#
#             contract_period  group_visits        age  \
# cluster_km
# 2                  2.352475      0.215842  28.477228
# 3                  1.948494      0.341521  28.167987
#
#             avg_additional_charges_total  month_to_end_contract  lifetime  \
# cluster_km
# 2                             135.457501               2.198020  2.809901
# 3                             131.622204               1.856577  2.440571
#
#             avg_class_frequency_total  avg_class_frequency_current_month  \
# cluster_km
# 2                            1.660461                           1.477324
# 3                            1.247634                           1.012983
#
#                churn
# cluster_km
# 2           0.443564
# 3           0.514263

# %% [markdown]
# Сравним средние результаты по кластерам 2 и 3 с характерными особенностями, которые определяют кластеры 0 и 4:
#
# 1. Гендерное равенство не влияет на отток
# 2. Проживание или работа в районе, где находится фитнес-центр не имеет значения
# 3. Наличие контактного телефона у всех клиентов не влияет на отток
# 4. Посещение групповых занятий - уровень гораздо ниже, возможно влияние с точки зрения вовлеченности
# 5. Возраст - 28 лет против 30
# 6. Суммарная выручка от других услуг фитнес-центра существенно ниже
# 7. Время с момента первого обращения - около 2-3 месяцев
# 8. Количество посещений в неделю - менее 2

# %% [markdown]
# ### Заключение

# %% [markdown]
# Построена матрица расстояний и дендрограмма ([см. раздел 4.1](#conclusion_4.1)).
# Определены средние значения признаков по кластерам и определены характерные особенности каждого кластера ([см. раздел 4.2](#conclusion_4.2)).
# Построены распределения признаков по кластерам, выполнена их качественная оценка ([см. раздел 4.3](#conclusion_4.3)).
# Рассчитана доля оттока по кластерам, в топе по удержанию кластеры 0 и 4, максимальный отток наблюдается в кластерах 2 и 3 ([см. раздел 4.4](#conclusion_4.4)).

# %% [markdown]
# <a id="step_5"> </a>
# ## Общий вывод

# %% [markdown]
# Получены и загружены исходные данные, выполнена их предварительная обработка ([см. раздел 1](#step_1)).
# Выполнен исследовательский анализ данных:
# 1. Получена общая информация по данным, выделены характерные особенности по средним значениям ([см. раздел 2.1](#conclusion_2.1)).
# 2. Изучено распределение числовых признаков целевой переменной `churn` ([см. раздел 2.2](#conclusion_2.2)).
# 3. Рассмотрены средние значения признаков целевой переменной `churn` по группам - тех, кто ушел в отток и тех, кто остался ([см. раздел 2.3](#conclusion_2.3)).
# 4. Построена тепловая карта матрицы корреляций признаков набора данных, факторы выделены в отдельные категории по степени влияния на целевую переменную `churn` ([см. раздел 2.4](#conclusion_2.4)).
# 5. Обнаружены две пары мультиколлинеарных признаков:
# * `contract_period` и `month_to_end_contract`
# * `avg_class_frequency_total` и `avg_class_frequency_current_month`
#
# Выполнено обучение модели на train-выборке двумя способами:
# * логистической регрессией - `LogisticRegression()`
# * случайным лесом - `RandomForestRegressor()`
#
# На основании полученных значений метрик можно считать, что модель, обученная логистической регрессией, показала себя лучше. У обеих моделей очень высокие результаты по Accuracy (больше 0,91), а также высокие результаты по Precision и Recall.
#
# Построена модель, позволяющая прогнозировать вероятность оттока по каждому клиенту. Явных зависимостей факта оттока от одного конкретного признака из рассматриваемых не обнаружено. Выполнена кластеризация клиентов.
#
# Исходя из полученных результатов, наименьший отток клиентов характерен для кластеров 0 и 4, для которых выделеяются следующие общие признаки:
# 1. Гендерное равенство
# 2. Практически все клиенты проживают или работают в районе, где находится фитнес-центр
# 3. Наличие контактного телефона у всех клиентов
# 4. Посещение групповых занятий - примерно половина клиентов
# 5. Возраст - 30 лет
# 6. Одинаковая суммарная выручка от других услуг фитнес-центра
# 7. Время с момента первого обращения - около 5 месяцев
# 8. Количество посещений в неделю - 2 и более
#
# При этом в сравнении с кластерами 2 и 3 (с наибольшим оттоком), можно отметить:
# 1. Гендерное равенство не влияет на отток
# 2. Проживание или работа в районе, где находится фитнес-центр не имеет значения
# 3. Наличие контактного телефона у всех клиентов не влияет на отток
# 4. Посещение групповых занятий - уровень гораздо ниже, возможно влияние с точки зрения вовлеченности
# 5. Возраст - 28 лет против 30
# 6. Суммарная выручка от других услуг фитнес-центра существенно ниже
# 7. Время с момента первого обращения - около 2-3 месяцев
# 8. Количество посещений в неделю - менее 2
#
# Скорее всего, есть дополнительные признаки, характеризующие индивидуальную вовлеченность клиентов. Вовлеченные клиенты чаще посещают фитнес-центр, тратят больше денег на дополнительные услуги и ходят на групповые занятия.
#
# Рекомендуется при разработке стратегии для взаимодействия с клиентами и их удержания учесть следующие факторы:
# 1. Пол клиента не имеет значения.
# 2. Предпочтительнее, чтобы клиенты проживали или работали вблизи фитнес-центра
# 3. Обратить внимание на количество посещений (не менее 2 раз в неделю)
# 4. Обратить внимание на посещение групповых занятий.
# 4. Средний возраст клиента составляет 30 лет.
#
# **Предлагается попробовать применить прогрессивную шкалу скидок на следующий абонемент для пользователей, которые посещают фитнес-центр не менее 2 раз в неделю, а также ходят на групповые занятия. Это должно быть еще одним фактором увеличения вовлеченности и снижения оттока.**
